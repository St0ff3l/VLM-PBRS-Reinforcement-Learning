# %%
# Cell 1: Imports and environment setup
from pathlib import Path
import re
import sys

import gymnasium as gym
import torch
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.monitor import Monitor

# Resolve project root by searching upward for the folder that contains `vlm`.
start_dir = Path.cwd().resolve()
project_root = next((p for p in [start_dir, *start_dir.parents] if (p / "vlm").is_dir()), start_dir)
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from vlm.llava_client import query_llava_position

print(f"Project root: {project_root}")
print(f"Python executable: {sys.executable}")
print(f"CUDA available: {torch.cuda.is_available()}")
assert torch.cuda.is_available(), "CUDA is required for this notebook (expected RTX 3070)."
device = "cuda"
print(f"Using device: {device}")
print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Project root: D:\CodeFiles\RL-Gymnasium-PACSPL602013-Final-Project
# Python executable: d:\CodeFiles\RL-Gymnasium-PACSPL602013-Final-Project\final_project_env\Scripts\python.exe
# CUDA available: True
# Using device: cuda
# GPU: NVIDIA GeForce RTX 3070 Laptop GPU

# %%
# Cell 2: Reward-shaping logic and multi-threshold callback
import re
import gymnasium as gym
from stable_baselines3.common.callbacks import BaseCallback

PROMPT = "Observe the car. Is it on the LEFT slope, RIGHT slope, or BOTTOM? Reply with only one word."

def normalize_label(raw_text: str) -> str:
    cleaned = re.sub(r"[^A-Za-z]", "", raw_text).upper()
    if "LEFT" in cleaned: return "LEFT"
    if "RIGHT" in cleaned: return "RIGHT"
    return "BOTTOM"

def label_to_phi(label: str) -> float:
    if label == "LEFT": return 0.5
    if label == "RIGHT": return 1.0
    return 0.0

class VLMRewardShapingWrapper(gym.Wrapper):
    def __init__(self, env, sample_every_n: int = 128, gamma: float = 0.99):
        super().__init__(env)
        self.sample_every_n = sample_every_n
        self.gamma = gamma
        self.step_count = 0
        self.total_steps = 0
        self.current_label = "BOTTOM"
        self.current_phi = 0.0
        self.previous_phi = 0.0

    def reset(self, **kwargs):
        # Reset state to prevent episode leakage
        self.step_count = 0
        self.current_phi = 0.0
        self.previous_phi = 0.0
        self.current_label = "BOTTOM"
        return self.env.reset(**kwargs)

    def step(self, action):
        obs, reward_env, terminated, truncated, info = self.env.step(action)
        self.step_count += 1
        self.total_steps += 1
        self.previous_phi = self.current_phi

        # 1. Kinematic Reward (Dense proprioceptive feedback)
        position = float(obs[0])
        progress_reward = 0.0
        if position > -0.4:
            progress_reward = (position + 0.4) * 2.0

        # 2. Semantic Reward (Sparse VLM guidance)
        if self.step_count >= self.sample_every_n:
            self.step_count = 0
            try:
                frame = self.env.render()
                llava_reply = query_llava_position(frame=frame, model="llava:7b", prompt=PROMPT)
                self.current_label = normalize_label(llava_reply)
                phi = label_to_phi(self.current_label)
                
                # Decay VLM reliance over time
                decay = max(0.0, 1.0 - (self.total_steps / 200_000.0))
                self.current_phi = phi * decay
                
                print(f"[VLM] step={self.total_steps}, label={self.current_label}, phi={self.current_phi:.2f}")
            except Exception as e:
                self.current_label = "BOTTOM"
                self.current_phi = 0.0

        # 3. Hybrid Reward Fusion (Strict PBRS Math)
        shaping_reward = (self.gamma * self.current_phi) - self.previous_phi
        reward_total = reward_env + shaping_reward + progress_reward

        info["reward_env"] = reward_env
        info["shaping_reward"] = shaping_reward
        info["progress_reward"] = progress_reward
        info["reward_total"] = reward_total
        
        return obs, reward_total, terminated, truncated, info

class MultiThresholdCallback(BaseCallback):
    def __init__(self, thresholds=None, verbose=0):
        super().__init__(verbose)
        self.thresholds = thresholds or [-195, -190, -180, -170, -160]
        self.threshold_steps = {t: None for t in self.thresholds}

    def _on_step(self) -> bool:
        for info in self.locals.get("infos", []):
            if "episode" in info:
                episode_reward = info["episode"]["r"]
                for threshold in self.thresholds:
                    if episode_reward >= threshold and self.threshold_steps[threshold] is None:
                        self.threshold_steps[threshold] = self.num_timesteps
                        print(f"VLM-PPO reached {threshold} at step {self.num_timesteps}")
        return True

# %%
# Cell 3: Train VLM-PPO and export multi-threshold JSON
from pathlib import Path
import json
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
import torch

log_dir = Path("logs_and_results")
log_dir.mkdir(parents=True, exist_ok=True)

thresholds = [-195, -190, -180, -170, -160]
sample_every_n = 128
gamma = 0.99
total_timesteps_cap = 150_000

base_env = gym.make("MountainCar-v0", render_mode="rgb_array")
monitored_env = Monitor(base_env, str(log_dir / "vlm_monitor.csv"))
train_env = VLMRewardShapingWrapper(monitored_env, sample_every_n=sample_every_n, gamma=gamma)

model = PPO(
    policy="MlpPolicy",
    env=train_env,
    ent_coef=0.05,
    learning_rate=0.001,
    n_steps=2048,
    verbose=1,
    tensorboard_log=str(log_dir / "tensorboard_vlm_multi_thresh"),
    device="cuda" if torch.cuda.is_available() else "cpu",
)

callback = MultiThresholdCallback(thresholds=thresholds)
print("Start VLM-PPO training for 150000 timesteps")
model.learn(
    total_timesteps=total_timesteps_cap,
    callback=callback,
    tb_log_name="ppo_vlm_multi_thresh",
)

model_path = log_dir / "vlm_multi_thresh"
model.save(str(model_path))
print(f"Saved model: {model_path}.zip")

vlm_results = {str(t): (s if s is not None else 150000) for t, s in callback.threshold_steps.items()}
json_path = log_dir / "vlm_thresholds.json"
with open(json_path, "w", encoding="utf-8") as f:
    json.dump(vlm_results, f, indent=2)
print(f"Saved threshold metrics: {json_path}")

train_env.close()
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# Start VLM-PPO training for 150000 timesteps
# Logging to logs_and_results\tensorboard_vlm_multi_thresh\ppo_vlm_multi_thresh_1
# d:\CodeFiles\RL-Gymnasium-PACSPL602013-Final-Project\final_project_env\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# [VLM] step=128, label=LEFT, phi=0.50
# [VLM] step=328, label=LEFT, phi=0.50
# [VLM] step=528, label=LEFT, phi=0.50
# [VLM] step=728, label=LEFT, phi=0.50
# [VLM] step=928, label=RIGHT, phi=1.00
# [VLM] step=1128, label=LEFT, phi=0.50
# [VLM] step=1328, label=RIGHT, phi=0.99
# [VLM] step=1528, label=LEFT, phi=0.50
# [VLM] step=1728, label=LEFT, phi=0.50
# [VLM] step=1928, label=LEFT, phi=0.50
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -200     |
# | time/              |          |
# |    fps             | 59       |
# |    iterations      | 1        |
# |    time_elapsed    | 34       |
# |    total_timesteps | 2048     |
# ---------------------------------
# [VLM] step=2128, label=LEFT, phi=0.49
# [VLM] step=2328, label=LEFT, phi=0.49
# [VLM] step=2528, label=LEFT, phi=0.49
# [VLM] step=2728, label=LEFT, phi=0.49
# [VLM] step=2928, label=LEFT, phi=0.49
# [VLM] step=3128, label=LEFT, phi=0.49
# [VLM] step=3328, label=LEFT, phi=0.49
# [VLM] step=3528, label=RIGHT, phi=0.98
# [VLM] step=3728, label=LEFT, phi=0.49
# [VLM] step=3928, label=LEFT, phi=0.49
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 2           |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009183878 |
# |    clip_fraction        | 0.0239      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.000382    |
# |    learning_rate        | 0.001       |
# |    loss                 | 2.2         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.000694   |
# |    value_loss           | 50.8        |
# -----------------------------------------
# [VLM] step=4128, label=LEFT, phi=0.49
# [VLM] step=4328, label=RIGHT, phi=0.98
# [VLM] step=4528, label=LEFT, phi=0.49
# [VLM] step=4728, label=LEFT, phi=0.49
# [VLM] step=4928, label=LEFT, phi=0.49
# [VLM] step=5128, label=RIGHT, phi=0.97
# [VLM] step=5328, label=LEFT, phi=0.49
# [VLM] step=5528, label=LEFT, phi=0.49
# [VLM] step=5728, label=LEFT, phi=0.49
# [VLM] step=5928, label=RIGHT, phi=0.97
# [VLM] step=6128, label=LEFT, phi=0.48
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 3           |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010056388 |
# |    clip_fraction        | 0.0227      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.0247      |
# |    learning_rate        | 0.001       |
# |    loss                 | 2.43        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00148    |
# |    value_loss           | 38.5        |
# -----------------------------------------
# [VLM] step=6328, label=RIGHT, phi=0.97
# [VLM] step=6528, label=RIGHT, phi=0.97
# [VLM] step=6728, label=LEFT, phi=0.48
# [VLM] step=6928, label=LEFT, phi=0.48
# [VLM] step=7128, label=LEFT, phi=0.48
# [VLM] step=7328, label=LEFT, phi=0.48
# [VLM] step=7528, label=LEFT, phi=0.48
# [VLM] step=7728, label=LEFT, phi=0.48
# [VLM] step=7928, label=LEFT, phi=0.48
# [VLM] step=8128, label=LEFT, phi=0.48
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 63          |
# |    iterations           | 4           |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008053013 |
# |    clip_fraction        | 0.0126      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.0578      |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.9         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.000366   |
# |    value_loss           | 23.5        |
# -----------------------------------------
# [VLM] step=8328, label=RIGHT, phi=0.96
# [VLM] step=8528, label=RIGHT, phi=0.96
# [VLM] step=8728, label=LEFT, phi=0.48
# [VLM] step=8928, label=RIGHT, phi=0.96
# [VLM] step=9128, label=LEFT, phi=0.48
# [VLM] step=9328, label=LEFT, phi=0.48
# [VLM] step=9528, label=LEFT, phi=0.48
# [VLM] step=9728, label=LEFT, phi=0.48
# [VLM] step=9928, label=LEFT, phi=0.48
# [VLM] step=10128, label=RIGHT, phi=0.95
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -200       |
# | time/                   |            |
# |    fps                  | 63         |
# |    iterations           | 5          |
# |    time_elapsed         | 160        |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01227899 |
# |    clip_fraction        | 0.0416     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.08      |
# |    explained_variance   | 0.0951     |
# |    learning_rate        | 0.001      |
# |    loss                 | 1.51       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.00234   |
# |    value_loss           | 14.7       |
# ----------------------------------------
# [VLM] step=10328, label=LEFT, phi=0.47
# [VLM] step=10528, label=LEFT, phi=0.47
# [VLM] step=10728, label=RIGHT, phi=0.95
# [VLM] step=10928, label=LEFT, phi=0.47
# [VLM] step=11128, label=LEFT, phi=0.47
# [VLM] step=11328, label=LEFT, phi=0.47
# [VLM] step=11528, label=LEFT, phi=0.47
# [VLM] step=11728, label=LEFT, phi=0.47
# [VLM] step=11928, label=RIGHT, phi=0.94
# [VLM] step=12128, label=LEFT, phi=0.47
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 63          |
# |    iterations           | 6           |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009764697 |
# |    clip_fraction        | 0.0549      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.116       |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.08        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00275    |
# |    value_loss           | 10.5        |
# -----------------------------------------
# [VLM] step=12328, label=LEFT, phi=0.47
# [VLM] step=12528, label=LEFT, phi=0.47
# [VLM] step=12728, label=LEFT, phi=0.47
# [VLM] step=12928, label=LEFT, phi=0.47
# [VLM] step=13128, label=RIGHT, phi=0.93
# [VLM] step=13328, label=LEFT, phi=0.47
# [VLM] step=13528, label=LEFT, phi=0.47
# [VLM] step=13728, label=LEFT, phi=0.47
# [VLM] step=13928, label=LEFT, phi=0.47
# [VLM] step=14128, label=LEFT, phi=0.46
# [VLM] step=14328, label=LEFT, phi=0.46
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 63          |
# |    iterations           | 7           |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009681648 |
# |    clip_fraction        | 0.0137      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.0297     |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.854       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00254    |
# |    value_loss           | 6.28        |
# -----------------------------------------
# [VLM] step=14528, label=LEFT, phi=0.46
# [VLM] step=14728, label=RIGHT, phi=0.93
# [VLM] step=14928, label=LEFT, phi=0.46
# [VLM] step=15128, label=RIGHT, phi=0.92
# [VLM] step=15328, label=LEFT, phi=0.46
# [VLM] step=15528, label=RIGHT, phi=0.92
# [VLM] step=15728, label=LEFT, phi=0.46
# [VLM] step=15928, label=LEFT, phi=0.46
# [VLM] step=16128, label=RIGHT, phi=0.92
# [VLM] step=16328, label=RIGHT, phi=0.92
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 200       |
# |    ep_rew_mean          | -200      |
# | time/                   |           |
# |    fps                  | 63        |
# |    iterations           | 8         |
# |    time_elapsed         | 257       |
# |    total_timesteps      | 16384     |
# | train/                  |           |
# |    approx_kl            | 0.0113659 |
# |    clip_fraction        | 0.0927    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.03     |
# |    explained_variance   | 0.209     |
# |    learning_rate        | 0.001     |
# |    loss                 | 0.49      |
# |    n_updates            | 70        |
# |    policy_gradient_loss | -0.00916  |
# |    value_loss           | 4.52      |
# ---------------------------------------
# [VLM] step=16528, label=LEFT, phi=0.46
# [VLM] step=16728, label=LEFT, phi=0.46
# [VLM] step=16928, label=RIGHT, phi=0.92
# [VLM] step=17128, label=RIGHT, phi=0.91
# [VLM] step=17328, label=RIGHT, phi=0.91
# [VLM] step=17528, label=LEFT, phi=0.46
# [VLM] step=17728, label=LEFT, phi=0.46
# [VLM] step=17928, label=LEFT, phi=0.46
# [VLM] step=18128, label=LEFT, phi=0.45
# [VLM] step=18328, label=RIGHT, phi=0.91
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 63          |
# |    iterations           | 9           |
# |    time_elapsed         | 288         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008697648 |
# |    clip_fraction        | 0.0595      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.282       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.597       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0042     |
# |    value_loss           | 2.93        |
# -----------------------------------------
# [VLM] step=18528, label=LEFT, phi=0.45
# [VLM] step=18728, label=LEFT, phi=0.45
# [VLM] step=18928, label=LEFT, phi=0.45
# [VLM] step=19128, label=LEFT, phi=0.45
# [VLM] step=19328, label=RIGHT, phi=0.90
# [VLM] step=19528, label=LEFT, phi=0.45
# [VLM] step=19728, label=RIGHT, phi=0.90
# [VLM] step=19928, label=RIGHT, phi=0.90
# [VLM] step=20128, label=RIGHT, phi=0.90
# [VLM] step=20328, label=LEFT, phi=0.45
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 10          |
# |    time_elapsed         | 319         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010459892 |
# |    clip_fraction        | 0.0636      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.93       |
# |    explained_variance   | 0.414       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.609       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00547    |
# |    value_loss           | 3           |
# -----------------------------------------
# [VLM] step=20528, label=LEFT, phi=0.45
# [VLM] step=20728, label=LEFT, phi=0.45
# [VLM] step=20928, label=RIGHT, phi=0.90
# [VLM] step=21128, label=LEFT, phi=0.45
# [VLM] step=21328, label=LEFT, phi=0.45
# [VLM] step=21528, label=RIGHT, phi=0.89
# [VLM] step=21728, label=LEFT, phi=0.45
# [VLM] step=21928, label=LEFT, phi=0.45
# [VLM] step=22128, label=RIGHT, phi=0.89
# [VLM] step=22328, label=LEFT, phi=0.44
# [VLM] step=22528, label=LEFT, phi=0.44
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 63          |
# |    iterations           | 11          |
# |    time_elapsed         | 352         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.011147505 |
# |    clip_fraction        | 0.0597      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.84       |
# |    explained_variance   | 0.495       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.558       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0063     |
# |    value_loss           | 2.07        |
# -----------------------------------------
# [VLM] step=22728, label=LEFT, phi=0.44
# [VLM] step=22928, label=LEFT, phi=0.44
# [VLM] step=23128, label=RIGHT, phi=0.88
# [VLM] step=23328, label=LEFT, phi=0.44
# [VLM] step=23528, label=LEFT, phi=0.44
# [VLM] step=23728, label=LEFT, phi=0.44
# [VLM] step=23928, label=LEFT, phi=0.44
# [VLM] step=24128, label=LEFT, phi=0.44
# [VLM] step=24328, label=RIGHT, phi=0.88
# [VLM] step=24528, label=LEFT, phi=0.44
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 64           |
# |    iterations           | 12           |
# |    time_elapsed         | 383          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0014186889 |
# |    clip_fraction        | 0.0273       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.849       |
# |    explained_variance   | 0.526        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.376        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | 0.00231      |
# |    value_loss           | 1.06         |
# ------------------------------------------
# [VLM] step=24728, label=RIGHT, phi=0.88
# [VLM] step=24928, label=LEFT, phi=0.44
# [VLM] step=25128, label=LEFT, phi=0.44
# [VLM] step=25328, label=LEFT, phi=0.44
# [VLM] step=25528, label=LEFT, phi=0.44
# [VLM] step=25728, label=LEFT, phi=0.44
# [VLM] step=25928, label=LEFT, phi=0.44
# [VLM] step=26128, label=LEFT, phi=0.43
# [VLM] step=26328, label=LEFT, phi=0.43
# [VLM] step=26528, label=RIGHT, phi=0.87
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 13          |
# |    time_elapsed         | 414         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.005507328 |
# |    clip_fraction        | 0.0672      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.786      |
# |    explained_variance   | 0.624       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.214       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00825    |
# |    value_loss           | 0.916       |
# -----------------------------------------
# [VLM] step=26728, label=LEFT, phi=0.43
# [VLM] step=26928, label=LEFT, phi=0.43
# [VLM] step=27128, label=LEFT, phi=0.43
# [VLM] step=27328, label=LEFT, phi=0.43
# [VLM] step=27528, label=RIGHT, phi=0.86
# [VLM] step=27728, label=LEFT, phi=0.43
# [VLM] step=27928, label=LEFT, phi=0.43
# [VLM] step=28128, label=RIGHT, phi=0.86
# [VLM] step=28328, label=RIGHT, phi=0.86
# [VLM] step=28528, label=LEFT, phi=0.43
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 64           |
# |    iterations           | 14           |
# |    time_elapsed         | 446          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0065014046 |
# |    clip_fraction        | 0.0575       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.717       |
# |    explained_variance   | 0.625        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.244        |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00672     |
# |    value_loss           | 0.843        |
# ------------------------------------------
# [VLM] step=28728, label=LEFT, phi=0.43
# [VLM] step=28928, label=LEFT, phi=0.43
# [VLM] step=29128, label=RIGHT, phi=0.85
# [VLM] step=29328, label=LEFT, phi=0.43
# [VLM] step=29528, label=LEFT, phi=0.43
# [VLM] step=29728, label=LEFT, phi=0.43
# [VLM] step=29928, label=LEFT, phi=0.43
# [VLM] step=30128, label=LEFT, phi=0.42
# [VLM] step=30328, label=LEFT, phi=0.42
# [VLM] step=30528, label=LEFT, phi=0.42
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 64           |
# |    iterations           | 15           |
# |    time_elapsed         | 478          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0057452596 |
# |    clip_fraction        | 0.0516       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.638       |
# |    explained_variance   | 0.69         |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.221        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00824     |
# |    value_loss           | 0.806        |
# ------------------------------------------
# [VLM] step=30728, label=LEFT, phi=0.42
# [VLM] step=30928, label=RIGHT, phi=0.85
# [VLM] step=31128, label=LEFT, phi=0.42
# [VLM] step=31328, label=RIGHT, phi=0.84
# [VLM] step=31528, label=RIGHT, phi=0.84
# [VLM] step=31728, label=RIGHT, phi=0.84
# [VLM] step=31928, label=LEFT, phi=0.42
# [VLM] step=32128, label=RIGHT, phi=0.84
# [VLM] step=32328, label=RIGHT, phi=0.84
# [VLM] step=32528, label=RIGHT, phi=0.84
# [VLM] step=32728, label=LEFT, phi=0.42
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 63           |
# |    iterations           | 16           |
# |    time_elapsed         | 512          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0037187145 |
# |    clip_fraction        | 0.068        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.572       |
# |    explained_variance   | 0.735        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.174        |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00775     |
# |    value_loss           | 0.471        |
# ------------------------------------------
# [VLM] step=32928, label=LEFT, phi=0.42
# [VLM] step=33128, label=LEFT, phi=0.42
# [VLM] step=33328, label=LEFT, phi=0.42
# [VLM] step=33528, label=LEFT, phi=0.42
# [VLM] step=33728, label=LEFT, phi=0.42
# [VLM] step=33928, label=LEFT, phi=0.42
# [VLM] step=34128, label=LEFT, phi=0.41
# [VLM] step=34328, label=RIGHT, phi=0.83
# [VLM] step=34528, label=LEFT, phi=0.41
# [VLM] step=34728, label=LEFT, phi=0.41
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 64           |
# |    iterations           | 17           |
# |    time_elapsed         | 543          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0015528164 |
# |    clip_fraction        | 0.0236       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.482       |
# |    explained_variance   | 0.865        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.361        |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00412     |
# |    value_loss           | 0.625        |
# ------------------------------------------
# [VLM] step=34928, label=LEFT, phi=0.41
# [VLM] step=35128, label=LEFT, phi=0.41
# [VLM] step=35328, label=LEFT, phi=0.41
# [VLM] step=35528, label=LEFT, phi=0.41
# [VLM] step=35728, label=RIGHT, phi=0.82
# [VLM] step=35928, label=LEFT, phi=0.41
# [VLM] step=36128, label=LEFT, phi=0.41
# [VLM] step=36328, label=LEFT, phi=0.41
# [VLM] step=36528, label=RIGHT, phi=0.82
# [VLM] step=36728, label=RIGHT, phi=0.82
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 64           |
# |    iterations           | 18           |
# |    time_elapsed         | 574          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0012652354 |
# |    clip_fraction        | 0.0172       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.456       |
# |    explained_variance   | 0.884        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.275        |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00177     |
# |    value_loss           | 0.958        |
# ------------------------------------------
# [VLM] step=36928, label=LEFT, phi=0.41
# [VLM] step=37128, label=RIGHT, phi=0.81
# [VLM] step=37328, label=RIGHT, phi=0.81
# [VLM] step=37528, label=LEFT, phi=0.41
# [VLM] step=37728, label=LEFT, phi=0.41
# [VLM] step=37928, label=LEFT, phi=0.41
# [VLM] step=38128, label=RIGHT, phi=0.81
# [VLM] step=38328, label=LEFT, phi=0.40
# [VLM] step=38528, label=RIGHT, phi=0.81
# [VLM] step=38728, label=LEFT, phi=0.40
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 64           |
# |    iterations           | 19           |
# |    time_elapsed         | 605          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0006244461 |
# |    clip_fraction        | 0.0162       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.445       |
# |    explained_variance   | 0.865        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.419        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | 0.000232     |
# |    value_loss           | 1.88         |
# ------------------------------------------
# [VLM] step=38928, label=LEFT, phi=0.40
# [VLM] step=39128, label=LEFT, phi=0.40
# [VLM] step=39328, label=LEFT, phi=0.40
# [VLM] step=39528, label=LEFT, phi=0.40
# [VLM] step=39728, label=RIGHT, phi=0.80
# [VLM] step=39928, label=LEFT, phi=0.40
# [VLM] step=40128, label=LEFT, phi=0.40
# [VLM] step=40328, label=LEFT, phi=0.40
# [VLM] step=40528, label=RIGHT, phi=0.80
# [VLM] step=40728, label=LEFT, phi=0.40
# [VLM] step=40928, label=RIGHT, phi=0.80
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 64           |
# |    iterations           | 20           |
# |    time_elapsed         | 638          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0024852653 |
# |    clip_fraction        | 0.00996      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.418       |
# |    explained_variance   | 0.867        |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.01         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000392    |
# |    value_loss           | 2.52         |
# ------------------------------------------
# [VLM] step=41128, label=LEFT, phi=0.40
# [VLM] step=41328, label=RIGHT, phi=0.79
# [VLM] step=41528, label=LEFT, phi=0.40
# [VLM] step=41728, label=LEFT, phi=0.40
# [VLM] step=41928, label=LEFT, phi=0.40
# [VLM] step=42128, label=LEFT, phi=0.39
# [VLM] step=42328, label=RIGHT, phi=0.79
# [VLM] step=42528, label=LEFT, phi=0.39
# [VLM] step=42728, label=LEFT, phi=0.39
# [VLM] step=42928, label=RIGHT, phi=0.79
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 64           |
# |    iterations           | 21           |
# |    time_elapsed         | 670          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0021698466 |
# |    clip_fraction        | 0.0207       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.377       |
# |    explained_variance   | 0.863        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.387        |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000802    |
# |    value_loss           | 1.03         |
# ------------------------------------------
# [VLM] step=43128, label=RIGHT, phi=0.78
# [VLM] step=43328, label=LEFT, phi=0.39
# [VLM] step=43528, label=RIGHT, phi=0.78
# [VLM] step=43728, label=LEFT, phi=0.39
# [VLM] step=43928, label=RIGHT, phi=0.78
# [VLM] step=44128, label=RIGHT, phi=0.78
# [VLM] step=44328, label=LEFT, phi=0.39
# [VLM] step=44528, label=LEFT, phi=0.39
# [VLM] step=44728, label=LEFT, phi=0.39
# [VLM] step=44928, label=RIGHT, phi=0.78
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 64           |
# |    iterations           | 22           |
# |    time_elapsed         | 701          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0028230238 |
# |    clip_fraction        | 0.0329       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.366       |
# |    explained_variance   | 0.878        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.114        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00256     |
# |    value_loss           | 0.404        |
# ------------------------------------------
# [VLM] step=45128, label=LEFT, phi=0.39
# [VLM] step=45328, label=LEFT, phi=0.39
# [VLM] step=45528, label=LEFT, phi=0.39
# [VLM] step=45728, label=RIGHT, phi=0.77
# [VLM] step=45928, label=LEFT, phi=0.39
# [VLM] step=46128, label=LEFT, phi=0.38
# [VLM] step=46328, label=RIGHT, phi=0.77
# [VLM] step=46528, label=LEFT, phi=0.38
# [VLM] step=46728, label=LEFT, phi=0.38
# [VLM] step=46928, label=LEFT, phi=0.38
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 64           |
# |    iterations           | 23           |
# |    time_elapsed         | 732          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0023840405 |
# |    clip_fraction        | 0.0457       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.396       |
# |    explained_variance   | 0.796        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.553        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 2.37         |
# ------------------------------------------
# [VLM] step=47128, label=LEFT, phi=0.38
# [VLM] step=47328, label=LEFT, phi=0.38
# [VLM] step=47528, label=LEFT, phi=0.38
# [VLM] step=47728, label=LEFT, phi=0.38
# [VLM] step=47928, label=LEFT, phi=0.38
# [VLM] step=48128, label=LEFT, phi=0.38
# [VLM] step=48328, label=RIGHT, phi=0.76
# [VLM] step=48528, label=LEFT, phi=0.38
# [VLM] step=48728, label=LEFT, phi=0.38
# [VLM] step=48928, label=LEFT, phi=0.38
# [VLM] step=49128, label=LEFT, phi=0.38
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 64           |
# |    iterations           | 24           |
# |    time_elapsed         | 766          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0072006704 |
# |    clip_fraction        | 0.0853       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.448       |
# |    explained_variance   | 0.849        |
# |    learning_rate        | 0.001        |
# |    loss                 | 2.26         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00315     |
# |    value_loss           | 4.95         |
# ------------------------------------------
# [VLM] step=49328, label=LEFT, phi=0.38
# [VLM] step=49528, label=LEFT, phi=0.38
# [VLM] step=49728, label=LEFT, phi=0.38
# [VLM] step=49928, label=LEFT, phi=0.38
# [VLM] step=50128, label=LEFT, phi=0.37
# [VLM] step=50328, label=LEFT, phi=0.37
# [VLM] step=50528, label=RIGHT, phi=0.75
# [VLM] step=50728, label=LEFT, phi=0.37
# [VLM] step=50928, label=LEFT, phi=0.37
# [VLM] step=51128, label=LEFT, phi=0.37
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 64           |
# |    iterations           | 25           |
# |    time_elapsed         | 797          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0051447777 |
# |    clip_fraction        | 0.103        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.583       |
# |    explained_variance   | 0.903        |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.09         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00269     |
# |    value_loss           | 4.77         |
# ------------------------------------------
# [VLM] step=51328, label=RIGHT, phi=0.74
# [VLM] step=51528, label=RIGHT, phi=0.74
# [VLM] step=51728, label=LEFT, phi=0.37
# [VLM] step=51928, label=LEFT, phi=0.37
# [VLM] step=52128, label=RIGHT, phi=0.74
# [VLM] step=52328, label=RIGHT, phi=0.74
# [VLM] step=52528, label=LEFT, phi=0.37
# [VLM] step=52728, label=LEFT, phi=0.37
# [VLM] step=52928, label=LEFT, phi=0.37
# [VLM] step=53128, label=LEFT, phi=0.37
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 64           |
# |    iterations           | 26           |
# |    time_elapsed         | 828          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0061193993 |
# |    clip_fraction        | 0.126        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.666       |
# |    explained_variance   | 0.918        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.658        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00751     |
# |    value_loss           | 3.42         |
# ------------------------------------------
# [VLM] step=53328, label=RIGHT, phi=0.73
# [VLM] step=53528, label=RIGHT, phi=0.73
# [VLM] step=53728, label=RIGHT, phi=0.73
# [VLM] step=53928, label=RIGHT, phi=0.73
# [VLM] step=54128, label=RIGHT, phi=0.73
# [VLM] step=54328, label=RIGHT, phi=0.73
# [VLM] step=54528, label=LEFT, phi=0.36
# [VLM] step=54728, label=RIGHT, phi=0.73
# [VLM] step=54928, label=LEFT, phi=0.36
# [VLM] step=55128, label=LEFT, phi=0.36
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 27          |
# |    time_elapsed         | 858         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.005193683 |
# |    clip_fraction        | 0.0912      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.671      |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.855       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00447    |
# |    value_loss           | 3.32        |
# -----------------------------------------
# [VLM] step=55328, label=RIGHT, phi=0.72
# VLM-PPO reached -195 at step 55374
# VLM-PPO reached -190 at step 55374
# VLM-PPO reached -180 at step 55374
# [VLM] step=55502, label=LEFT, phi=0.36
# VLM-PPO reached -170 at step 55510
# VLM-PPO reached -160 at step 55510
# [VLM] step=55638, label=LEFT, phi=0.36
# [VLM] step=55838, label=LEFT, phi=0.36
# [VLM] step=55994, label=LEFT, phi=0.36
# [VLM] step=56175, label=RIGHT, phi=0.72
# [VLM] step=56375, label=LEFT, phi=0.36
# [VLM] step=56520, label=LEFT, phi=0.36
# [VLM] step=56649, label=LEFT, phi=0.36
# [VLM] step=56849, label=LEFT, phi=0.36
# [VLM] step=57021, label=RIGHT, phi=0.71
# [VLM] step=57221, label=LEFT, phi=0.36
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 197         |
# |    ep_rew_mean          | -197        |
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 28          |
# |    time_elapsed         | 895         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.008683586 |
# |    clip_fraction        | 0.0658      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.665      |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.03        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00812    |
# |    value_loss           | 3.22        |
# -----------------------------------------
# [VLM] step=57421, label=RIGHT, phi=0.71
# [VLM] step=57621, label=LEFT, phi=0.36
# [VLM] step=57821, label=LEFT, phi=0.36
# [VLM] step=58021, label=LEFT, phi=0.35
# [VLM] step=58221, label=LEFT, phi=0.35
# [VLM] step=58421, label=LEFT, phi=0.35
# [VLM] step=58621, label=LEFT, phi=0.35
# [VLM] step=58821, label=LEFT, phi=0.35
# [VLM] step=59021, label=LEFT, phi=0.35
# [VLM] step=59221, label=LEFT, phi=0.35
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 197         |
# |    ep_rew_mean          | -197        |
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 29          |
# |    time_elapsed         | 926         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.012548419 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.659      |
# |    explained_variance   | 0.769       |
# |    learning_rate        | 0.001       |
# |    loss                 | 6.07        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 2.29e-05    |
# |    value_loss           | 28.2        |
# -----------------------------------------
# [VLM] step=59421, label=LEFT, phi=0.35
# [VLM] step=59621, label=RIGHT, phi=0.70
# [VLM] step=59762, label=LEFT, phi=0.35
# [VLM] step=59962, label=RIGHT, phi=0.70
# [VLM] step=60162, label=RIGHT, phi=0.70
# [VLM] step=60362, label=RIGHT, phi=0.70
# [VLM] step=60562, label=RIGHT, phi=0.70
# [VLM] step=60715, label=LEFT, phi=0.35
# [VLM] step=60915, label=LEFT, phi=0.35
# [VLM] step=61115, label=RIGHT, phi=0.69
# [VLM] step=61315, label=LEFT, phi=0.35
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 196         |
# |    ep_rew_mean          | -196        |
# | time/                   |             |
# |    fps                  | 63          |
# |    iterations           | 30          |
# |    time_elapsed         | 961         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.014305273 |
# |    clip_fraction        | 0.082       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.794      |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.771       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00554    |
# |    value_loss           | 2.53        |
# -----------------------------------------
# [VLM] step=61498, label=LEFT, phi=0.35
# [VLM] step=61686, label=LEFT, phi=0.35
# [VLM] step=61845, label=RIGHT, phi=0.69
# [VLM] step=61976, label=LEFT, phi=0.35
# [VLM] step=62137, label=LEFT, phi=0.34
# [VLM] step=62337, label=LEFT, phi=0.34
# [VLM] step=62537, label=RIGHT, phi=0.69
# [VLM] step=62703, label=RIGHT, phi=0.69
# [VLM] step=62848, label=RIGHT, phi=0.69
# [VLM] step=63048, label=LEFT, phi=0.34
# [VLM] step=63248, label=LEFT, phi=0.34
# [VLM] step=63384, label=RIGHT, phi=0.68
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 192          |
# |    ep_rew_mean          | -192         |
# | time/                   |              |
# |    fps                  | 63           |
# |    iterations           | 31           |
# |    time_elapsed         | 997          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0030795475 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.642       |
# |    explained_variance   | 0.948        |
# |    learning_rate        | 0.001        |
# |    loss                 | 5.68         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 12.1         |
# ------------------------------------------
# [VLM] step=63530, label=LEFT, phi=0.34
# [VLM] step=63730, label=RIGHT, phi=0.68
# [VLM] step=63903, label=LEFT, phi=0.34
# [VLM] step=64047, label=LEFT, phi=0.34
# [VLM] step=64202, label=RIGHT, phi=0.68
# [VLM] step=64402, label=LEFT, phi=0.34
# [VLM] step=64602, label=RIGHT, phi=0.68
# [VLM] step=64767, label=RIGHT, phi=0.68
# [VLM] step=64952, label=LEFT, phi=0.34
# [VLM] step=65104, label=RIGHT, phi=0.67
# [VLM] step=65304, label=LEFT, phi=0.34
# [VLM] step=65504, label=RIGHT, phi=0.67
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 190          |
# |    ep_rew_mean          | -190         |
# | time/                   |              |
# |    fps                  | 63           |
# |    iterations           | 32           |
# |    time_elapsed         | 1033         |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0037626321 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.583       |
# |    explained_variance   | 0.967        |
# |    learning_rate        | 0.001        |
# |    loss                 | 3.9          |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 14.7         |
# ------------------------------------------
# [VLM] step=65667, label=LEFT, phi=0.34
# [VLM] step=65836, label=RIGHT, phi=0.67
# [VLM] step=65984, label=LEFT, phi=0.34
# [VLM] step=66184, label=LEFT, phi=0.33
# [VLM] step=66335, label=RIGHT, phi=0.67
# [VLM] step=66483, label=LEFT, phi=0.33
# [VLM] step=66614, label=LEFT, phi=0.33
# [VLM] step=66814, label=LEFT, phi=0.33
# [VLM] step=66951, label=RIGHT, phi=0.67
# [VLM] step=67119, label=LEFT, phi=0.33
# [VLM] step=67254, label=RIGHT, phi=0.66
# [VLM] step=67430, label=LEFT, phi=0.33
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 185         |
# |    ep_rew_mean          | -185        |
# | time/                   |             |
# |    fps                  | 63          |
# |    iterations           | 33          |
# |    time_elapsed         | 1069        |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.007173181 |
# |    clip_fraction        | 0.0776      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.617      |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.001       |
# |    loss                 | 4.85        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00462    |
# |    value_loss           | 14.8        |
# -----------------------------------------
# [VLM] step=67596, label=LEFT, phi=0.33
# [VLM] step=67796, label=LEFT, phi=0.33
# [VLM] step=67971, label=LEFT, phi=0.33
# [VLM] step=68106, label=LEFT, phi=0.33
# [VLM] step=68300, label=LEFT, phi=0.33
# [VLM] step=68472, label=RIGHT, phi=0.66
# [VLM] step=68640, label=RIGHT, phi=0.66
# [VLM] step=68777, label=LEFT, phi=0.33
# [VLM] step=68934, label=LEFT, phi=0.33
# [VLM] step=69090, label=LEFT, phi=0.33
# [VLM] step=69248, label=LEFT, phi=0.33
# [VLM] step=69381, label=LEFT, phi=0.33
# [VLM] step=69556, label=LEFT, phi=0.33
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | -180        |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 34          |
# |    time_elapsed         | 1108        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.005768434 |
# |    clip_fraction        | 0.043       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.607      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.001       |
# |    loss                 | 4.35        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00209    |
# |    value_loss           | 11.9        |
# -----------------------------------------
# [VLM] step=69720, label=RIGHT, phi=0.65
# [VLM] step=69892, label=LEFT, phi=0.33
# [VLM] step=70057, label=LEFT, phi=0.32
# [VLM] step=70228, label=LEFT, phi=0.32
# [VLM] step=70364, label=LEFT, phi=0.32
# [VLM] step=70493, label=LEFT, phi=0.32
# [VLM] step=70630, label=LEFT, phi=0.32
# [VLM] step=70804, label=LEFT, phi=0.32
# [VLM] step=70937, label=LEFT, phi=0.32
# [VLM] step=71099, label=LEFT, phi=0.32
# [VLM] step=71299, label=LEFT, phi=0.32
# [VLM] step=71476, label=LEFT, phi=0.32
# [VLM] step=71635, label=RIGHT, phi=0.64
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 175         |
# |    ep_rew_mean          | -175        |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 35          |
# |    time_elapsed         | 1148        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.004453916 |
# |    clip_fraction        | 0.0408      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.537      |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.001       |
# |    loss                 | 3.5         |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00214    |
# |    value_loss           | 9.47        |
# -----------------------------------------
# [VLM] step=71787, label=LEFT, phi=0.32
# [VLM] step=71973, label=LEFT, phi=0.32
# [VLM] step=72142, label=RIGHT, phi=0.64
# [VLM] step=72318, label=LEFT, phi=0.32
# [VLM] step=72462, label=LEFT, phi=0.32
# [VLM] step=72628, label=LEFT, phi=0.32
# [VLM] step=72862, label=LEFT, phi=0.32
# [VLM] step=73001, label=LEFT, phi=0.32
# [VLM] step=73243, label=LEFT, phi=0.32
# [VLM] step=73401, label=LEFT, phi=0.32
# [VLM] step=73533, label=RIGHT, phi=0.63
# [VLM] step=73698, label=LEFT, phi=0.32
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 170         |
# |    ep_rew_mean          | -170        |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 36          |
# |    time_elapsed         | 1184        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.011815058 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.525      |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.001       |
# |    loss                 | 2.43        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00473    |
# |    value_loss           | 6.1         |
# -----------------------------------------
# [VLM] step=73861, label=LEFT, phi=0.32
# [VLM] step=74021, label=LEFT, phi=0.31
# [VLM] step=74176, label=LEFT, phi=0.31
# [VLM] step=74368, label=LEFT, phi=0.31
# [VLM] step=74536, label=LEFT, phi=0.31
# [VLM] step=74697, label=RIGHT, phi=0.63
# [VLM] step=74863, label=LEFT, phi=0.31
# [VLM] step=75017, label=LEFT, phi=0.31
# [VLM] step=75175, label=LEFT, phi=0.31
# [VLM] step=75339, label=LEFT, phi=0.31
# [VLM] step=75512, label=LEFT, phi=0.31
# [VLM] step=75701, label=LEFT, phi=0.31
# ------------------------------------------
# ...
# | train/                  |             |
# |    approx_kl            | 0.002494411 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.162      |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.001       |
# |    loss                 | 2.25        |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -1.38e-05   |
# |    value_loss           | 4.67        |
# -----------------------------------------
# [VLM] step=125282, label=LEFT, phi=0.19
# [VLM] step=125645, label=LEFT, phi=0.19
# [VLM] step=125899, label=LEFT, phi=0.19
# [VLM] step=126382, label=RIGHT, phi=0.37
# [VLM] step=126532, label=RIGHT, phi=0.37
# [VLM] step=126693, label=LEFT, phi=0.18
# [VLM] step=126845, label=LEFT, phi=0.18
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 123          |
# |    ep_rew_mean          | -123         |
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 62           |
# |    time_elapsed         | 1805         |
# |    total_timesteps      | 126976       |
# | train/                  |              |
# |    approx_kl            | 0.0032588958 |
# |    clip_fraction        | 0.0458       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.153       |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.9          |
# |    n_updates            | 610          |
# |    policy_gradient_loss | 0.0005       |
# |    value_loss           | 4.21         |
# ------------------------------------------
# [VLM] step=127553, label=LEFT, phi=0.18
# [VLM] step=128249, label=RIGHT, phi=0.36
# [VLM] step=128576, label=RIGHT, phi=0.36
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 120          |
# |    ep_rew_mean          | -120         |
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 63           |
# |    time_elapsed         | 1817         |
# |    total_timesteps      | 129024       |
# | train/                  |              |
# |    approx_kl            | 0.0021178017 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.121       |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 0.001        |
# |    loss                 | 2.53         |
# |    n_updates            | 620          |
# |    policy_gradient_loss | -4.97e-05    |
# |    value_loss           | 6.64         |
# ------------------------------------------
# [VLM] step=129296, label=LEFT, phi=0.18
# [VLM] step=129429, label=LEFT, phi=0.18
# [VLM] step=129705, label=LEFT, phi=0.18
# [VLM] step=130212, label=LEFT, phi=0.17
# [VLM] step=130562, label=RIGHT, phi=0.35
# [VLM] step=130730, label=LEFT, phi=0.17
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 122          |
# |    ep_rew_mean          | -122         |
# | time/                   |              |
# |    fps                  | 71           |
# |    iterations           | 64           |
# |    time_elapsed         | 1837         |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 0.0017742334 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.129       |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 0.001        |
# |    loss                 | 2.12         |
# |    n_updates            | 630          |
# |    policy_gradient_loss | 0.00134      |
# |    value_loss           | 6.42         |
# ------------------------------------------
# [VLM] step=131475, label=LEFT, phi=0.17
# [VLM] step=131630, label=RIGHT, phi=0.34
# [VLM] step=131758, label=LEFT, phi=0.17
# [VLM] step=132001, label=LEFT, phi=0.17
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 122         |
# |    ep_rew_mean          | -122        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 65          |
# |    time_elapsed         | 1852        |
# |    total_timesteps      | 133120      |
# | train/                  |             |
# |    approx_kl            | 0.011067906 |
# |    clip_fraction        | 0.04        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.115      |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.11        |
# |    n_updates            | 640         |
# |    policy_gradient_loss | 0.00204     |
# |    value_loss           | 2.2         |
# -----------------------------------------
# [VLM] step=133129, label=RIGHT, phi=0.33
# [VLM] step=133290, label=RIGHT, phi=0.33
# [VLM] step=133432, label=RIGHT, phi=0.33
# [VLM] step=133683, label=LEFT, phi=0.17
# [VLM] step=133831, label=LEFT, phi=0.17
# [VLM] step=134391, label=LEFT, phi=0.16
# [VLM] step=134637, label=LEFT, phi=0.16
# [VLM] step=134788, label=RIGHT, phi=0.33
# [VLM] step=135035, label=LEFT, phi=0.16
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 123         |
# |    ep_rew_mean          | -123        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 66          |
# |    time_elapsed         | 1881        |
# |    total_timesteps      | 135168      |
# | train/                  |             |
# |    approx_kl            | 0.006871124 |
# |    clip_fraction        | 0.0429      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.132      |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.68        |
# |    n_updates            | 650         |
# |    policy_gradient_loss | 0.000111    |
# |    value_loss           | 5.04        |
# -----------------------------------------
# [VLM] step=135302, label=LEFT, phi=0.16
# [VLM] step=135545, label=LEFT, phi=0.16
# [VLM] step=135696, label=LEFT, phi=0.16
# [VLM] step=135874, label=LEFT, phi=0.16
# [VLM] step=136033, label=RIGHT, phi=0.32
# [VLM] step=136180, label=LEFT, phi=0.16
# [VLM] step=136442, label=LEFT, phi=0.16
# [VLM] step=136596, label=LEFT, phi=0.16
# [VLM] step=136830, label=LEFT, phi=0.16
# [VLM] step=137165, label=LEFT, phi=0.16
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 123          |
# |    ep_rew_mean          | -123         |
# | time/                   |              |
# |    fps                  | 71           |
# |    iterations           | 67           |
# |    time_elapsed         | 1912         |
# |    total_timesteps      | 137216       |
# | train/                  |              |
# |    approx_kl            | 0.0011276372 |
# |    clip_fraction        | 0.0247       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.124       |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 0.001        |
# |    loss                 | 3.36         |
# |    n_updates            | 660          |
# |    policy_gradient_loss | 0.00113      |
# |    value_loss           | 6.12         |
# ------------------------------------------
# [VLM] step=137782, label=LEFT, phi=0.16
# [VLM] step=137925, label=RIGHT, phi=0.31
# [VLM] step=138057, label=RIGHT, phi=0.31
# [VLM] step=138491, label=LEFT, phi=0.15
# [VLM] step=138641, label=LEFT, phi=0.15
# [VLM] step=138803, label=LEFT, phi=0.15
# [VLM] step=138956, label=LEFT, phi=0.15
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 122          |
# |    ep_rew_mean          | -122         |
# | time/                   |              |
# |    fps                  | 71           |
# |    iterations           | 68           |
# |    time_elapsed         | 1935         |
# |    total_timesteps      | 139264       |
# | train/                  |              |
# |    approx_kl            | 0.0052129123 |
# |    clip_fraction        | 0.0443       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.146       |
# |    explained_variance   | 0.988        |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.33         |
# |    n_updates            | 670          |
# |    policy_gradient_loss | 0.000927     |
# |    value_loss           | 3.08         |
# ------------------------------------------
# [VLM] step=139319, label=LEFT, phi=0.15
# [VLM] step=139468, label=LEFT, phi=0.15
# [VLM] step=139833, label=LEFT, phi=0.15
# [VLM] step=139989, label=LEFT, phi=0.15
# [VLM] step=140145, label=RIGHT, phi=0.30
# [VLM] step=140306, label=LEFT, phi=0.15
# [VLM] step=140783, label=LEFT, phi=0.15
# [VLM] step=141057, label=RIGHT, phi=0.29
# [VLM] step=141193, label=RIGHT, phi=0.29
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 125         |
# |    ep_rew_mean          | -125        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 69          |
# |    time_elapsed         | 1963        |
# |    total_timesteps      | 141312      |
# | train/                  |             |
# |    approx_kl            | 0.002127326 |
# |    clip_fraction        | 0.0298      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.137      |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.001       |
# |    loss                 | 2.23        |
# |    n_updates            | 680         |
# |    policy_gradient_loss | 0.00168     |
# |    value_loss           | 4.37        |
# -----------------------------------------
# [VLM] step=141851, label=LEFT, phi=0.15
# [VLM] step=142216, label=RIGHT, phi=0.29
# [VLM] step=142384, label=LEFT, phi=0.14
# [VLM] step=142538, label=LEFT, phi=0.14
# [VLM] step=142820, label=LEFT, phi=0.14
# [VLM] step=143065, label=RIGHT, phi=0.28
# [VLM] step=143230, label=LEFT, phi=0.14
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 125          |
# |    ep_rew_mean          | -125         |
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 70           |
# |    time_elapsed         | 1986         |
# |    total_timesteps      | 143360       |
# | train/                  |              |
# |    approx_kl            | 0.0038356215 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.14        |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.001        |
# |    loss                 | 2.14         |
# |    n_updates            | 690          |
# |    policy_gradient_loss | -2.67e-05    |
# |    value_loss           | 4.33         |
# ------------------------------------------
# [VLM] step=143389, label=LEFT, phi=0.14
# [VLM] step=143563, label=RIGHT, phi=0.28
# [VLM] step=143813, label=RIGHT, phi=0.28
# [VLM] step=143953, label=LEFT, phi=0.14
# [VLM] step=144217, label=RIGHT, phi=0.28
# [VLM] step=144451, label=LEFT, phi=0.14
# [VLM] step=144696, label=LEFT, phi=0.14
# [VLM] step=144849, label=LEFT, phi=0.14
# [VLM] step=145221, label=LEFT, phi=0.14
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 128          |
# |    ep_rew_mean          | -128         |
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 71           |
# |    time_elapsed         | 2014         |
# |    total_timesteps      | 145408       |
# | train/                  |              |
# |    approx_kl            | 0.0028806226 |
# |    clip_fraction        | 0.0263       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.14        |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.8          |
# |    n_updates            | 700          |
# |    policy_gradient_loss | 0.000657     |
# |    value_loss           | 4.3          |
# ------------------------------------------
# [VLM] step=146054, label=LEFT, phi=0.13
# [VLM] step=146387, label=LEFT, phi=0.13
# [VLM] step=146547, label=LEFT, phi=0.13
# [VLM] step=146693, label=LEFT, phi=0.13
# [VLM] step=146939, label=LEFT, phi=0.13
# [VLM] step=147092, label=RIGHT, phi=0.26
# [VLM] step=147322, label=LEFT, phi=0.13
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 127          |
# |    ep_rew_mean          | -127         |
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 72           |
# |    time_elapsed         | 2037         |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0049021393 |
# |    clip_fraction        | 0.0351       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.135       |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.88         |
# |    n_updates            | 710          |
# |    policy_gradient_loss | 0.00101      |
# |    value_loss           | 4.27         |
# ------------------------------------------
# [VLM] step=147477, label=RIGHT, phi=0.26
# [VLM] step=147635, label=LEFT, phi=0.13
# [VLM] step=147766, label=RIGHT, phi=0.26
# [VLM] step=147917, label=LEFT, phi=0.13
# [VLM] step=148159, label=LEFT, phi=0.13
# [VLM] step=148433, label=RIGHT, phi=0.26
# [VLM] step=148839, label=LEFT, phi=0.13
# [VLM] step=148982, label=LEFT, phi=0.13
# [VLM] step=149344, label=LEFT, phi=0.13
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 126          |
# |    ep_rew_mean          | -126         |
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 73           |
# |    time_elapsed         | 2065         |
# |    total_timesteps      | 149504       |
# | train/                  |              |
# |    approx_kl            | 0.0028530802 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.128       |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.21         |
# |    n_updates            | 720          |
# |    policy_gradient_loss | 0.00138      |
# |    value_loss           | 4.79         |
# ------------------------------------------
# [VLM] step=149605, label=LEFT, phi=0.13
# [VLM] step=149779, label=LEFT, phi=0.13
# [VLM] step=150505, label=LEFT, phi=0.12
# [VLM] step=150872, label=LEFT, phi=0.12
# [VLM] step=151246, label=RIGHT, phi=0.24
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 127         |
# |    ep_rew_mean          | -127        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 74          |
# |    time_elapsed         | 2082        |
# |    total_timesteps      | 151552      |
# | train/                  |             |
# |    approx_kl            | 0.002310884 |
# |    clip_fraction        | 0.0233      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.15       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.91        |
# |    n_updates            | 730         |
# |    policy_gradient_loss | -0.000976   |
# |    value_loss           | 5.96        |
# -----------------------------------------
# Saved model: logs_and_results\vlm_multi_thresh.zip
# Saved threshold metrics: logs_and_results\vlm_thresholds.json
